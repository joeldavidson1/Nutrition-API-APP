# %% [markdown]
# # Proximates

# %%
import pandas as pd
df_proximates = pd.read_excel('COFID_dataset.xlsx', sheet_name='1.3 Proximates')
df_proximates
# Out:
#      Food Code                                          Food Name  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2       13-145                             Ackee, canned, drained
# 3       13-146                                        Agar, dried
# 4       13-147                    Agar, dried, soaked and drained
# ...        ...                                                ...
# 2884    12-515            Yogurt, whole milk, twin pot, not fruit
# 2885    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2886    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2887   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2888   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group Previous  \
# 0                                                   NaN   NaN      NaN
# ...

# %%
df_proximates = df_proximates.drop([0, 1])
df_proximates = df_proximates.drop(df_proximates.columns[[4, 6, 8, 15, 26, 28, 29, 30, 31, 31, 32, 33, 34, 36, 37, 38, 40, 41, 42, 43, 44]] , axis=1)
df_proximates
# Out:
#      Food Code                                          Food Name  \
# 2       13-145                             Ackee, canned, drained
# 3       13-146                                        Agar, dried
# 4       13-147                    Agar, dried, soaked and drained
# 5       13-148                               Alfalfa sprouts, raw
# 6       13-801                                   Allspice, ground
# ...        ...                                                ...
# 2884    12-515            Yogurt, whole milk, twin pot, not fruit
# 2885    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2886    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2887   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2888   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group  \
# 2                                                8 cans    DG
# ...

# %%
# Rename columns to remove duplications
df_proximates.rename({'Energy (kcal) (kcal)' : 'Energy (kcal)', 'Energy (kJ) (kJ)': 'Energy (kJ)'}, axis=1, inplace=True)
df_proximates
# Out:
#      Food Code                                          Food Name  \
# 2       13-145                             Ackee, canned, drained
# 3       13-146                                        Agar, dried
# 4       13-147                    Agar, dried, soaked and drained
# 5       13-148                               Alfalfa sprouts, raw
# 6       13-801                                   Allspice, ground
# ...        ...                                                ...
# 2884    12-515            Yogurt, whole milk, twin pot, not fruit
# 2885    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2886    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2887   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2888   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group  \
# 2                                                8 cans    DG
# ...

# %% [markdown]
# # Inorganics

# %%
df_inorganics = pd.read_excel('COFID_dataset.xlsx', sheet_name='1.4 Inorganics')
df_inorganics
# Out:
#                                                        Food Name  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2      13-145                             Ackee, canned, drained
# 3      13-146                                        Agar, dried
# 4      13-147                    Agar, dried, soaked and drained
# ...       ...                                                ...
# 2884   12-515            Yogurt, whole milk, twin pot, not fruit
# 2885   12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2886   11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2887  11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2888  11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group Previous  \
# 0                                                   NaN   NaN      NaN
# ...

# %%
# Add missing column name to first column
df_inorganics.rename(columns={' ': 'Food Code'}, inplace=True)

# %%
df_inorganics = df_inorganics.drop([0, 1])
df_inorganics = df_inorganics.drop(columns=['Description', 'Previous', 'Main data references', 'Footnote'])
df_inorganics
# Out:
#      Food Code                                          Food Name Group  \
# 2       13-145                             Ackee, canned, drained    DG
# 3       13-146                                        Agar, dried    DG
# 4       13-147                    Agar, dried, soaked and drained    DG
# 5       13-148                               Alfalfa sprouts, raw    DG
# 6       13-801                                   Allspice, ground     H
# ...        ...                                                ...   ...
# 2884    12-515            Yogurt, whole milk, twin pot, not fruit    BN
# 2885    12-531  Yogurt, whole milk, twin pot, thick and creamy...    BN
# 2886    11-960  Yorkshire pudding, made with semi-skimmed milk...    AT
# 2887   11-1135  Yorkshire pudding, made with skimmed milk, hom...    AT
# 2888   11-1146            Yorkshire pudding, made with whole milk    AT
#
#      Sodium (mg) Potassium (mg) Calcium (mg) Magnesium (mg) Phosphorus (mg)  \
# ...

# %% [markdown]
# # Vitamins

# %%
df_vitamins = pd.read_excel('COFID_dataset.xlsx', sheet_name='1.5 Vitamins')
df_vitamins
# Out:
#      Food Code                                          Food Name  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2       13-145                             Ackee, canned, drained
# 3       13-146                                        Agar, dried
# 4       13-147                    Agar, dried, soaked and drained
# ...        ...                                                ...
# 2884    12-515            Yogurt, whole milk, twin pot, not fruit
# 2885    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2886    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2887   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2888   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group Previous  \
# 0                                                   NaN   NaN      NaN
# ...

# %%
df_vitamins = df_vitamins.drop([0, 1])
df_vitamins = df_vitamins.drop(columns=['Description', 'Previous', 'Main data references', 'Footnote', 'Retinol Equivalent (µg)', 'Niacin equivalent (mg)'])
df_vitamins
# Out:
#      Food Code                                          Food Name Group  \
# 2       13-145                             Ackee, canned, drained    DG
# 3       13-146                                        Agar, dried    DG
# 4       13-147                    Agar, dried, soaked and drained    DG
# 5       13-148                               Alfalfa sprouts, raw    DG
# 6       13-801                                   Allspice, ground     H
# ...        ...                                                ...   ...
# 2884    12-515            Yogurt, whole milk, twin pot, not fruit    BN
# 2885    12-531  Yogurt, whole milk, twin pot, thick and creamy...    BN
# 2886    11-960  Yorkshire pudding, made with semi-skimmed milk...    AT
# 2887   11-1135  Yorkshire pudding, made with skimmed milk, hom...    AT
# 2888   11-1146            Yorkshire pudding, made with whole milk    AT
#
#      Retinol (µg) Carotene (µg) Vitamin D (µg) Vitamin E (mg) Vitamin K1 (µg)  \
# ...

# %% [markdown]
# # Merging the dataframes

# %%
df_all = df_proximates.merge(df_inorganics)
df_all = df_all.merge(df_vitamins)
df_all
# Out:
#      Food Code                                          Food Name  \
# 0       13-145                             Ackee, canned, drained
# 1       13-146                                        Agar, dried
# 2       13-147                    Agar, dried, soaked and drained
# 3       13-148                               Alfalfa sprouts, raw
# 4       13-801                                   Allspice, ground
# ...        ...                                                ...
# 2882    12-515            Yogurt, whole milk, twin pot, not fruit
# 2883    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2884    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2886   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group  \
# 0                                                8 cans    DG
# ...

# %%
# df_all = df_all.fillna("N/A")

# %% [markdown]
# # Removing duplicates

# %%
df_all['Food Code'].is_unique
# Out:
# False

# %%
df_all[df_all.duplicated(['Food Code'], keep=False)]
# Out:
#      Food Code                                          Food Name  \
# 51      13-669  Aubergine, flesh and skin, roasted in rapeseed...
# 2823    13-669                                    Watercress, raw
#
#                                             Description Group  \
# 51    11 samples, UK and imported, roasted in a smal...    DG
# 2823                        11 samples, UK and imported    DG
#
#                                    Main data references Water (g) Protein (g)  \
# 51    PHE, Nutrient analysis of fresh and processed ...      83.9         2.1
# 2823  PHE, Nutrient analysis of fresh and processed ...      94.8         1.9
#
#      Fat (g) Carbohydrate (g) Energy (kcal)  ... Thiamin (mg) Riboflavin (mg)  \
# 51       3.8              5.2            62  ...         0.03            0.03
# 2823     0.3               Tr            10  ...         0.16            0.06
#
#      Niacin (mg) Tryptophan/60 (mg) Vitamin B6 (mg) Vitamin B12 (µg)  \
# ...

# %% [markdown]
# ### Change one of the food codes to one that doesn't exist

# %%
new_food_code = '13-000'
df_all[df_all['Food Code'] == new_food_code]
# Out:
# Empty DataFrame
# Columns: [Food Code, Food Name, Description, Group, Main data references, Water (g), Protein (g), Fat (g), Carbohydrate (g), Energy (kcal), Energy (kJ), Starch (g), Total sugars (g), Glucose (g), Galactose (g), Fructose (g), Sucrose (g), Maltose (g), Lactose (g), Alcohol (g), NSP (g), AOAC fibre (g), Satd FA /100g fd (g), Mono FA /100g food (g), Poly FA /100g food (g), Trans FAs /100g food (g), Cholesterol (mg), Sodium (mg), Potassium (mg), Calcium (mg), Magnesium (mg), Phosphorus (mg), Iron (mg), Copper (mg), Zinc (mg), Chloride (mg), Manganese (mg), Selenium (µg), Iodine (µg), Retinol (µg), Carotene (µg), Vitamin D (µg), Vitamin E (mg), Vitamin K1 (µg), Thiamin (mg), Riboflavin (mg), Niacin (mg), Tryptophan/60 (mg), Vitamin B6 (mg), Vitamin B12 (µg), Folate (µg), Pantothenate (mg), Biotin (µg), Vitamin C (mg)]
# Index: []
#
# [0 rows x 54 columns]

# %%
df_all.at[51, 'Food Code'] = new_food_code

# %%
df_all['Food Code'].is_unique
# Out:
# True

# %% [markdown]
# # Removing food items with Group = 'BTM' as this was not provided in the CoFID PDF

# %%
df_all[df_all['Group'] == 'BTM']
# Out:
#      Food Code                                          Food Name  \
# 92      12-500  Baking fat and margarine (75-90% fat), hard block
# 838     12-501         Cooking fat, compound, not polyunsaturated
# 1208    12-502                       Ghee made from vegetable oil
#
#                                             Description Group  \
# 92    10 samples, 4 products, including Stork and ow...   BTM
# 838   6 samples, 3 products, including Cookeen, Trex...   BTM
# 1208                              5 samples, 3 products   BTM
#
#                                    Main data references Water (g) Protein (g)  \
# 92    DH, Nutrient analysis of a range of processed ...      22.2          Tr
# 838   DH, Nutrient analysis of a range of processed ...       0.2          Tr
# 1208  DH, Nutrient analysis of a range of processed ...        Tr         0.1
#
#      Fat (g) Carbohydrate (g) Energy (kcal)  ... Thiamin (mg) Riboflavin (mg)  \
# ...

# %%
df_all.drop(df_all[df_all['Group'] == 'BTM'].index, inplace=True)

# %% [markdown]
# # Trace (Tr) amounts and N

# %%
import numpy as np

# Replace 'Tr' with a small positive value
df_all.replace('Tr', 0.01, inplace=True)

# Replace 'N' with NaN
df_all.replace('N', np.nan, inplace=True)

# Replacing blank spaces with NaN
df_all.replace(r'^\s+$', pd.notna, regex=True, inplace=True)

df_all.fillna(np.nan)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 10
#       7 df_all.replace('N', np.nan, inplace=True)
#       9 # Replacing blank spaces with NaN
# ---> 10 df_all.replace(r'^\s+$', pd.nan, regex=True, inplace=True)
#      12 df_all.fillna(np.nan)
#
# AttributeError: module 'pandas' has no attribute 'nan'

# %%
print(df_all.dtypes)
# Out:
# Food Code                   object
# Food Name                   object
# Description                 object
# Group                       object
# Main data references        object
# Water (g)                   object
# Protein (g)                 object
# Fat (g)                     object
# Carbohydrate (g)            object
# Energy (kcal)               object
# Energy (kJ)                 object
# Starch (g)                  object
# Total sugars (g)            object
# Glucose (g)                 object
# Galactose (g)               object
# Fructose (g)                object
# Sucrose (g)                 object
# Maltose (g)                 object
# Lactose (g)                 object
# Alcohol (g)                 object
# NSP (g)                     object
# AOAC fibre (g)              object
# Satd FA /100g fd (g)        object
# Mono FA /100g food (g)      object
# Poly FA /100g food (g)      object
# Trans FAs /100g food (g)    object
# Cholesterol (mg)            object
# ...

# %% [markdown]
# # Dataframe to CSV file

# %%
df_all.to_csv('combined_nutrition_tables.csv', index=False, na_rep='NULL')

# %% [markdown]
# ### Add manually the 'Food Groups' from Appendix B https://assets.publishing.service.gov.uk/media/60538e66d3bf7f03249bac58/McCance_and_Widdowsons_Composition_of_Foods_integrated_dataset_2021.pdf as no dataset exists

# %%
import csv 

food_groups_dict = {
    'A': 'Cereals and cereal products',
    'AA': 'Flours, grains and starches',
    'AB': 'Sandwiches',
    'AC': 'Rice',
    'AD': 'Pasta',
    'AE': 'Pizzas',
    'AF': 'Breads',
    'AG': 'Rolls',
    'AI': 'Breakfast cereals',
    'AK': 'Infant cereal foods',
    'AM': 'Biscuits',
    'AN': 'Cakes',
    'AO': 'Pastry',
    'AP': 'Buns and pastries',
    'AS': 'Puddings',
    'AT': 'Savouries',
    'B': 'Milk and milk products',
    'BA': 'Cows milk',
    'BAB': 'Breakfast milk',
    'BAE': 'Skimmed milk',
    'BAH': 'Semi-skimmed milk',
    'BAK': 'Whole milk',
    'BAN': 'Channel Island milk',
    'BAR': 'Processed milks',
    'BC': 'Other milks',
    'BF': 'Infant formulas',
    'BFD': 'Whey-based modified milks',
    'BFG': 'Non-whey-based modified milks',
    'BFJ': 'Soya-based modified milks',
    'BFP': 'Follow-on formulas',
    'BH': 'Milk-based drinks',
    'BJ': 'Creams',
    'BJC': 'Fresh creams (pasteurised)',
    'BJF': 'Frozen creams (pasteurised)',
    'BJL': 'Sterilised creams',
    'BJP': 'UHT creams',
    'BJS': 'Imitation creams',
    'BL': 'Cheeses',
    'BN': 'Yogurts',
    'BNE': 'Whole milk yogurts',
    'BNH': 'Low fat yogurts',
    'BNS': 'Other yogurts',
    'BP': 'Ice creams',
    'BR': 'Puddings and chilled desserts',
    'BV': 'Savoury dishes and sauces',
    'C': 'Eggs',
    'CA': 'Eggs',
    'CD': 'Egg dishes',
    'CDE': 'Savoury egg dishes',
    'CDH': 'Sweet egg dishes',
    'D': 'Vegetables',
    'DA': 'Potatoes',
    'DAE': 'Early potatoes',
    'DAM': 'Main crop potatoes',
    'DAP': 'Chipped old potatoes',
    'DAR': 'Potato products',
    'DB': 'Beans and lentils',
    'DF': 'Peas',
    'DG': 'Vegetables, general',
    'DI': 'Vegetables, dried',
    'DR': 'Vegetable dishes',
    'F': 'Fruit',
    'FA': 'Fruit, general',
    'FC': 'Fruit juices',
    'G': 'Nuts and seeds',
    'GA': 'Nuts and seeds, general',
    'H': 'Herbs and spices',
    'J': 'Fish and fish products',
    'JA': 'White fish',
    'JC': 'Fatty fish',
    'JK': 'Crustacea',
    'JM': 'Molluscs',
    'JR': 'Fish products and dishes',
    'M': 'Meat and meat products',
    'MA': 'Meat',
    'MAA': 'Bacon',
    'MAC': 'Beef',
    'MAE': 'Lamb',
    'MAG': 'Pork',
    'MAI': 'Veal',
    'MC': 'Poultry',
    'MCA': 'Chicken',
    'MCC': 'Duck',
    'MCE': 'Goose',
    'MCG': 'Grouse',
    'MCI': 'Partridge',
    'MCK': 'Pheasant',
    'MCM': 'Pigeon',
    'MCO': 'Turkey',
    'ME': 'Game',
    'MEA': 'Hare',
    'MEC': 'Rabbit',
    'MEE': 'Venison',
    'MG': 'Offal',
    'MBG': 'Burgers and grillsteaks',
    'MI': 'Meat products',
    'MIG': 'Other meat products',
    'MR': 'Meat dishes',
    'O': 'Fats and oils',
    'OA': 'Spreading fats',
    'OB': 'Animal fats',
    'OC': 'Oils',
    'OE': 'Non-animal fats',
    'OF': 'Cooking fats',
    'P': 'Beverages',
    'PA': 'Powdered drinks, essences and infusions',
    'PAA': 'Powdered drinks and essences',
    'PAC': 'Infusions',
    'PC': 'Soft drinks',
    'PCA': 'Carbonated drinks',
    'PCC': 'Squash and cordials',
    'PE': 'Juices',
    'Q': 'Alcoholic beverages',
    'QA': 'Beers',
    'QC': 'Ciders',
    'QE': 'Wines',
    'QF': 'Fortified wines',
    'QG': 'Vermouths',
    'QI': 'Liqueurs',
    'QK': 'Spirits',
    'S': 'Sugars, preserves and snacks',
    'SC': 'Sugars, syrups and preserves',
    'SE': 'Confectionery',
    'SEA': 'Chocolate confectionery',
    'SEC': 'Non-chocolate confectionery',
    'SN': 'Savoury snacks',
    'SNA': 'Potato-based snacks',
    'SNB': 'Potato and mixed cereal snacks',
    'SNC': 'Non-potato snacks',
    'W': 'Soups, sauces and miscellaneous foods',
    'WA': 'Soups',
    'WAA': 'Homemade soups',
    'WAC': 'Canned soups',
    'WAE': 'Packet soups',
    'WC': 'Sauces',
    'WCD': 'Dairy sauces',
    'WCG': 'Salad sauces, dressings and pickles',
    'WCN': 'Non-salad sauces',
    'WE': 'Pickles and chutneys',
    'WY': 'Miscellaneous foods'
}

field_names = ['food_group', 'description']

# Writing the dictionary data to a CSV file
with open('food_groups.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header
    writer.writerow(['food_group', 'description'])
    
    # Write data
    for code, description in food_groups_dict.items():
        writer.writerow([code, description])

# %%
import csv
import json

with open('test.json') as json_file:
    food_data = json.load(json_file)

    for food_item in food_data:
        print(food_item['foodCode'])
# Out:
# 13-145
# 13-146
# 13-147
# 13-148
# 13-801
# 14-870
# 14-897
# 14-898
# 14-896
# 13-150
# 13-149
# 14-001
# 16-448
# 13-802
# 14-272
# 14-331
# 17-851
# 14-344
# 14-345
# 14-342
# 14-343
# 14-362
# 14-363
# 14-332
# 14-320
# 14-016
# 14-319
# 14-346
# 14-031
# 14-032
# 14-033
# 14-025
# 14-026
# 14-392
# 14-027
# 14-028
# 14-029
# 14-030
# 13-152
# 13-151
# 11-001
# 13-155
# 13-154
# 13-153
# 13-156
# 13-803
# 13-639
# 13-157
# 13-640
# 13-638
# 13-651
# 13-000
# 13-412
# 13-162
# 13-577
# 13-161
# 15-001
# 15-662
# 15-663
# 14-039
# 14-040
# 14-386
# 14-387
# 16-001
# 14-043
# 16-169
# 19-644
# 19-645
# 19-498
# 19-499
# 19-646
# 19-500
# 19-501
# 19-502
# 19-497
# 19-009
# 19-659
# 19-647
# 19-660
# 19-648
# 19-503
# 19-649
# 19-504
# 19-018
# 19-016
# 19-537
# 19-650
# 11-970
# 13-578
# 13-532
# 13-535
# 13-579
# 17-355
# 11-1029
# 12-556
# 14-318
# 14-347
# 11-1030
# 11-951
# 17-705
# 17-769
# 14-804
# 14-805
# 17-844
# 17-743
# 11-003
# 11-002
# 13-805
# 13-804
# 16-386
# ...
